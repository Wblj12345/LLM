# %%
import torch
from openai import OpenAI
client = OpenAI(
 api_key="sk-a1WcdiJnqNmcIozK9Y2scCvuqChNdFV7Qm3HgLePMM6pJG57",
 base_url="https://api.agicto.cn/v1"
)
print("环境配置完成！")
# Out:
# 环境配置完成！

# %%
import os
from openai import OpenAI
# 配置 agicto API
client = OpenAI(
 api_key=os.environ.get("AGICTO_API_KEY", "sk-a1WcdiJnqNmcIozK9Y2scCvuqChNdFV7Qm3HgLePMM6pJG57"),
 base_url="https://api.agicto.cn/v1"
)
MODEL = "gpt-4o-mini" # 或使用 "qwen-plus" 等其他模型
def chat_with_llm(messages, model=MODEL, temperature=0.7, max_tokens=1024):
 """发送消息给 LLM 并获取回复"""
 response = client.chat.completions.create(
 model=model,
 messages=messages,
 temperature=temperature,
 max_tokens=max_tokens
 )
 return response.choices[0].message.content
# 基础测试
messages = [{"role": "user", "content": "你好，请简单介绍下番茄的种植要点。"}]
reply = chat_with_llm(messages)
print(reply)
# Out:
# 你好！番茄的种植要点主要包括以下几个方面：
#
# 1. **选择品种**：根据气候和市场需求选择适合的番茄品种，如樱桃番茄、牛排番茄等。
#
# 2. **土壤准备**：番茄喜欢排水良好、富含有机质的土壤。可以在种植前施入腐熟的有机肥料，提升土壤的肥力和结构。
#
# 3. **播种和育苗**：可以选择直接播种或育苗。育苗时，种子可在温暖的环境中发芽，待幼苗长到10-15厘米高时再移植。
#
# 4. **光照和温度**：番茄需要充足的阳光，每天至少6-8小时的直射光照。适宜的生长温度为20-25°C。
#
# 5. **水分管理**：保持土壤适度湿润，但避免积水。生长期内应定期浇水，尤其在开花和结果期间。
#
# 6. **施肥**：在生长过程中，根据植物的需要进行适量施肥，通常在开花前后施用磷钾肥，有助于提高产量。
#
# 7. **病虫害防治**：定期检查植物，及时防治常见的病虫害，如白粉病、蚜虫等，可以使用生物农药或有机防治方法。
#
# 8. **支撑和修剪**：对于高杆品种，建议使用支架支撑，避免倒伏。适当修剪可以促进通风和光照，提高果实质量。
#
# 9. **收获**：当番茄成熟、色泽鲜艳时即可采摘。要注意轻拿轻放，避免损伤果实。
#
# 希望这些要点对你种植番茄有所帮助！

# %%
import os
import time
from openai import OpenAI
import matplotlib

matplotlib.use("Agg")
import matplotlib.pyplot as plt


# ── 配置 ──
API_KEY = os.environ.get("AGICTO_API_KEY", "sk-a1WcdiJnqNmcIozK9Y2scCvuqChNdFV7Qm3HgLePMM6pJG57")
BASE_URL = "https://api.agicto.cn/v1"
MODEL = "gpt-4o-mini"  # 或 gpt-4o-mini 等

client = OpenAI(api_key=API_KEY, base_url=BASE_URL)


def chat_with_llm(messages, model=MODEL, temperature=0.7, max_tokens=1024):
    """发送消息给 LLM 并获取回复"""
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature,
        max_tokens=max_tokens,
    )
    return response.choices[0].message.content


def benchmark_prompt(system_prompt, user_prompt, label=""):
    """发送单次请求并记录耗时和回答"""
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt},
    ]
    start = time.time()
    reply = chat_with_llm(messages, temperature=0.3)
    elapsed = time.time() - start
    print(f"\n{'=' * 60}")
    print(f"【{label}】")
    print(f"耗时: {elapsed:.1f}s")
    print(f"回答:\n{reply}")
    return reply


def main():
    # print("=" * 60)
    # print("  任务 A：LLM API 初体验与 Prompt Engineering")
    # print("=" * 60)

    # # ── 基础连通性测试 ──
    # print("\n--- 连通性测试 ---")
    # try:
    #     test_reply = chat_with_llm(
    #         [{"role": "user", "content": "你好，用一句话介绍自己。"}],
    #         temperature=0.3,
    #         max_tokens=100,
    #     )
    #     print(f"测试回复: {test_reply}")
    #     print("API 连接成功！")
    # except Exception as e:
    #     print(f"API 连接失败: {e}")
    #     print("请检查 API Key 和网络连接。")
    #     return

    # ── 实验 1：基础 prompt（无角色设定） ──
    benchmark_prompt(
        system_prompt="",
        user_prompt="番茄叶子发黄是什么原因？",
        label="实验1：基础 Prompt",
    )

    # ── 实验 2：角色设定 + 结构化要求 ──
    benchmark_prompt(
        system_prompt="你是一位有20年经验的农业植保专家。请用专业但易懂的语言回答农民的病害问题。",
        user_prompt="番茄叶子发黄是什么原因？请从以下方面分析：1. 可能的病害类型 2. 非病害原因（营养、水分等）3. 如何区分 4. 防治建议",
        label="实验2：角色设定+结构化",
    )

    # ── 实验 3：Few-shot + Chain of Thought ──
    benchmark_prompt(
        system_prompt="你是一位农业植保专家。请按以下步骤分析：先观察症状特征，再对比已知病害，最后给出诊断和建议。",
        user_prompt="""请参考以下诊断示例，对新的症状进行分析：
示例1：
- 症状：番茄叶片出现同心轮纹状褐色病斑
- 诊断：早疫病（Alternaria solani）。轮纹状病斑是典型特征。
- 建议：移除病叶，喷施代森锰锌或苯醚甲环唑。

示例2：
- 症状：番茄果实出现水渍状褐色凹陷斑，高湿环境下有白色霉层
- 诊断：晚疫病（Phytophthora infestans）。水渍状斑和白色霉层是关键特征。
- 建议：控制湿度，喷施烯酰吗啉或霜脲氰。

新症状：番茄叶片边缘出现 V 形黄褐色坏死斑，病健交界明显，多从下部叶片开始。
请逐步分析。""",
        label="实验3：Few-shot+逐步推理",
    )

    # # ── 多轮对话 ──
    # print("\n--- 多轮对话测试 ---")
    # messages = [
    #     {
    #         "role": "system",
    #         "content": "你是农业植保专家，专门帮助农民诊断和防治作物病害。回答要专业、实用、有依据。",
    #     }
    # ]

    # def multi_turn_chat(user_input):
    #     messages.append({"role": "user", "content": user_input})
    #     reply = chat_with_llm(messages, temperature=0.5)
    #     messages.append({"role": "assistant", "content": reply})
    #     print(f"\n你: {user_input}")
    #     print(f"专家: {reply}")
    #     return reply

    # multi_turn_chat(
    #     "我家的番茄最近叶子开始出现褐色斑点，集中在下部叶片，是怎么回事？"
    # )
    # multi_turn_chat("用什么药比较好？我现在手头有代森锰锌。")
    # multi_turn_chat("打药的频率应该是多少？")

    # ── 可视化对比 ──
    print("\n--- 生成对比图 ---")
    experiments = ["Basic Prompt", "Role & Structured", "Few-shot & Reasoning"]
    quality_scores = [3, 7, 9]  # 主观评分 1-10

    fig, ax = plt.subplots(figsize=(8, 5))
    bars = ax.barh(
        experiments, quality_scores, color=["#4e79a7", "#f28e2b", "#e15759"], edgecolor="black"
    )
    for bar, score in zip(bars, quality_scores):
        ax.text(
            score + 0.2,
            bar.get_y() + bar.get_height() / 2,
            f"{score}/10",
            va="center",
            fontsize=12,
            fontweight="bold",
        )
    ax.set_xlabel("Subjective Response Quality Score")
    ax.set_title("Comparison of Prompt Engineering Effects")
    ax.set_xlim(0, 11)
    ax.grid(True, alpha=0.3, axis="x")
    plt.tight_layout()
    plt.savefig("task_a_prompt_comparison.png", dpi=150, bbox_inches="tight")
    print("对比图已保存到 task_a_prompt_comparison.png")

    print("\n--- 任务 A 完成！---")


if __name__ == "__main__":
    main()
# Out:
# ============================================================
# 【实验1：基础 Prompt】
# 耗时: 4.4s
# 回答:
# 番茄叶子发黄可能由多种原因引起，以下是一些常见的原因：
#
# 1. **水分问题**：过多或过少的水分都可能导致叶子发黄。土壤过湿会导致根部缺氧，进而影响植物的健康；而缺水则会使植物无法正常吸收养分。
#
# 2. **营养缺乏**：缺乏氮、铁、镁等营养元素会导致叶子发黄。氮缺乏通常会使老叶发黄，而铁缺乏则会使新叶发黄。
#
# 3. **病虫害**：一些病虫害，如白粉病、根腐病或蚜虫、红蜘蛛等，都会导致叶子变黄。
#
# 4. **光照不足**：番茄需要充足的阳光，如果光照不足，叶子可能会变黄。
#
# 5. **温度问题**：极端的温度（过高或过低）也可能导致植物应激，从而使叶子发黄。
#
# 6. **土壤酸碱度**：土壤的酸碱度不适宜也可能影响植物的养分吸收，导致叶子发黄。
#
# 针对这些问题，可以通过调整浇水频率、施肥、改善光照条件、检查病虫害等方法来进行处理。
#
# ============================================================
# 【实验2：角色设定+结构化】
# 耗时: 10.5s
# 回答:
# 番茄叶子发黄是一个常见的问题，可能由多种因素引起。以下是对这一现象的分析：
#
# ### 1. 可能的病害类型
# - **真菌性病害**：如灰霉病、白粉病等，通常伴随有叶片上出现斑点或霉状物。
# - **细菌性病害**：如细菌性叶斑病，叶片上会出现水浸状斑点，逐渐变黄。
# - **病毒病**：如番茄斑驳病毒，通常会导致叶片变黄并出现变形。
#
# ### 2. 非病害原因（营养、水分等）
# - **营养缺乏**：氮、镁、铁等元素缺乏会导致叶片变黄。氮缺乏通常从下部叶片开始，镁缺乏则常见于老叶。
# - **水分问题**：过多或过少的水分都会影响根系的健康，导致叶片发黄。过湿会导致根腐病，过干则会造成植物缺水。
# - **土壤pH不适**：土壤酸碱度不适合会影响养分的吸收，导致叶片发黄。
#
# ### 3. 如何区分
# - **观察症状**：病害通常伴随特定的症状，如斑点、霉层等，而营养缺乏则多表现为均匀的黄化。
# - **生长阶段**：如果是老叶先发黄，可能是营养缺乏；如果是新叶发黄，可能是病害或根系问题。
# - **环境因素**：检查是否有过度浇水或干旱的情况，或土壤是否排水良好。
#
# ### 4. 防治建议
# - **病害防治**：如果确认是病害，使用相应的农药进行防治，并及时清理病残体。
# - **营养管理**：定期进行土壤检测，补充缺乏的营养元素。可以施用复合肥或特定的微量元素肥料。
# - **水分管理**：保持适宜的土壤湿度，避免积水，确保良好的排水性。
# - **轮作与种植管理**：避免连作，选择抗病品种，提高植株的抗逆性。
#
# 通过以上分析和建议，希望能帮助您更好地管理番茄的生长，减少叶片发黄的问题。如有进一步的疑问，欢迎随时咨询！
#
# ============================================================
# 【实验3：Few-shot+逐步推理】
# 耗时: 2.9s
# 回答:
# - 症状：番茄叶片边缘出现 V 形黄褐色坏死斑，病健交界明显，多从下部叶片开始。
#
# - 诊断：该症状特征符合番茄的叶枯病（Alternaria alternata）。V 形黄褐色坏死斑是该病害的典型表现，且病健交界明显，通常从下部叶片开始。
#
# - 建议：及时移除病叶，避免病害扩散。可喷施多菌灵或氟硅唑等药剂进行防治，同时注意通风透光，减少湿度，以降低病害发生的风险。
#
# --- 生成对比图 ---
# 对比图已保存到 task_a_prompt_comparison.png
#
# --- 任务 A 完成！---
